# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
n_pts = 500
np.random.seed(0)
Xa = np.array([np.random.normal(13,2,n_pts),
              np.random.normal(12,2,n_pts)]).T
Xb = np.array([np.random.normal(8,2,n_pts),
              np.random.normal(6,2,n_pts)]).T
X = np.vstack((Xa,Xb))  #all points
y = np.matrix(np.append(np.zeros(n_pts), np.ones(n_pts))).T
plt.scatter(X[:n_pts, 0], X[:n_pts,  1])
plt.scatter(X[n_pts:, 0], X[n_pts:,  1])

# %%
import tensorflow as tf
from tensorflow.keras.models import Sequential #linear
from tensorflow.keras.layers import Dense #every node is connected to every node in preceding layer
from tensorflow.keras.optimizers import Adam #Stochastic gradient decent (Adagrad, RMSprop)

# %%
model = Sequential()
model.add(Dense(units = 1 , input_shape=(2,), activation='sigmoid'))
#optimizer
adam = Adam(lr = 0.1)
model.compile(adam, loss='binary_crossentropy', metrics=['accuracy'])
history = model.fit(x=X, y=y, verbose=1, batch_size=50, epochs = 50, shuffle='true')
# Out:
# Train on 1000 samples
# Epoch 1/50
# 1000/1000 [==============================] - 0s 402us/sample - loss: 1.3879 - accuracy: 0.5290
# Epoch 2/50
# 1000/1000 [==============================] - 0s 32us/sample - loss: 0.5364 - accuracy: 0.7110
# Epoch 3/50
# 1000/1000 [==============================] - 0s 29us/sample - loss: 0.4419 - accuracy: 0.8310
# Epoch 4/50
# 1000/1000 [==============================] - 0s 34us/sample - loss: 0.3866 - accuracy: 0.8640
# Epoch 5/50
# 1000/1000 [==============================] - 0s 34us/sample - loss: 0.3415 - accuracy: 0.9080
# Epoch 6/50
# 1000/1000 [==============================] - 0s 31us/sample - loss: 0.3061 - accuracy: 0.9350
# Epoch 7/50
# 1000/1000 [==============================] - 0s 30us/sample - loss: 0.2795 - accuracy: 0.9360
# Epoch 8/50
# 1000/1000 [==============================] - 0s 33us/sample - loss: 0.2526 - accuracy: 0.9490
# Epoch 9/50
# 1000/1000 [==============================] - 0s 38us/sample - loss: 0.2316 - accuracy: 0.9570
# Epoch 10/50
# 1000/1000 [==============================] - 0s 29us/sample - loss: 0.2170 - accuracy: 0.9590
# Epoch 11/50
# 1000/1000 [==============================] - 0s 30us/sample - loss: 0.2031 - accuracy: 0.9570
# Epoch 12/50
# 1000/1000 [==============================] - 0s 31us/sample - loss: 0.1890 - accuracy: 0.9670
# Epoch 13/50
# 1000/1000 [==============================] - 0s 30us/sample - loss: 0.1763 - accuracy: 0.9650
# Epoch 14/50
# 1000/1000 [==============================] - 0s 30us/sample - loss: 0.1674 - accuracy: 0.9700
# Epoch 15/50
# 1000/1000 [==============================] - 0s 30us/sample - loss: 0.1620 - accuracy: 0.9630
# Epoch 16/50
# 1000/1000 [==============================] - 0s 33us/sample - loss: 0.1548 - accuracy: 0.9700
# Epoch 17/50
# 1000/1000 [==============================] - 0s 45us/sample - loss: 0.1490 - accuracy: 0.9660
# Epoch 18/50
# 1000/1000 [==============================] - 0s 35us/sample - loss: 0.1392 - accuracy: 0.9730
# Epoch 19/50
# 1000/1000 [==============================] - 0s 41us/sample - loss: 0.1350 - accuracy: 0.9740
# Epoch 20/50
# 1000/1000 [==============================] - 0s 37us/sample - loss: 0.1354 - accuracy: 0.9670
# Epoch 21/50
# 1000/1000 [==============================] - 0s 31us/sample - loss: 0.1264 - accuracy: 0.9740
# Epoch 22/50
# 1000/1000 [==============================] - 0s 31us/sample - loss: 0.1219 - accuracy: 0.9760
# Epoch 23/50
# 1000/1000 [==============================] - 0s 63us/sample - loss: 0.1184 - accuracy: 0.9760
# Epoch 24/50
# 1000/1000 [==============================] - 0s 28us/sample - loss: 0.1161 - accuracy: 0.9790
# Epoch 25/50
# 1000/1000 [==============================] - 0s 31us/sample - loss: 0.1166 - accuracy: 0.9710
# Epoch 26/50
# 1000/1000 [==============================] - 0s 30us/sample - loss: 0.1138 - accuracy: 0.9750
# Epoch 27/50
# 1000/1000 [==============================] - 0s 32us/sample - loss: 0.1126 - accuracy: 0.9720
# Epoch 28/50
# 1000/1000 [==============================] - 0s 31us/sample - loss: 0.1065 - accuracy: 0.9770
# Epoch 29/50
# 1000/1000 [==============================] - 0s 31us/sample - loss: 0.1030 - accuracy: 0.9780
# Epoch 30/50
# 1000/1000 [==============================] - 0s 33us/sample - loss: 0.1016 - accuracy: 0.9760
# Epoch 31/50
# 1000/1000 [==============================] - 0s 34us/sample - loss: 0.1006 - accuracy: 0.9790
# Epoch 32/50
# 1000/1000 [==============================] - 0s 31us/sample - loss: 0.0981 - accuracy: 0.9800
# Epoch 33/50
# 1000/1000 [==============================] - 0s 39us/sample - loss: 0.0980 - accuracy: 0.9760
# Epoch 34/50
# 1000/1000 [==============================] - 0s 34us/sample - loss: 0.0961 - accuracy: 0.9750
# Epoch 35/50
# 1000/1000 [==============================] - 0s 29us/sample - loss: 0.0960 - accuracy: 0.9800
# Epoch 36/50
# 1000/1000 [==============================] - 0s 29us/sample - loss: 0.1005 - accuracy: 0.9670
# Epoch 37/50
# 1000/1000 [==============================] - 0s 30us/sample - loss: 0.0941 - accuracy: 0.9720
# Epoch 38/50
# 1000/1000 [==============================] - 0s 27us/sample - loss: 0.0912 - accuracy: 0.9700
# Epoch 39/50
# 1000/1000 [==============================] - 0s 26us/sample - loss: 0.0884 - accuracy: 0.9760
# Epoch 40/50
# 1000/1000 [==============================] - 0s 26us/sample - loss: 0.0956 - accuracy: 0.9760
# Epoch 41/50
# 1000/1000 [==============================] - 0s 26us/sample - loss: 0.0861 - accuracy: 0.9780
# Epoch 42/50
# 1000/1000 [==============================] - 0s 30us/sample - loss: 0.0905 - accuracy: 0.9760
# Epoch 43/50
# 1000/1000 [==============================] - 0s 32us/sample - loss: 0.0924 - accuracy: 0.9680
# Epoch 44/50
# 1000/1000 [==============================] - 0s 32us/sample - loss: 0.0879 - accuracy: 0.9760
# Epoch 45/50
# 1000/1000 [==============================] - 0s 28us/sample - loss: 0.0883 - accuracy: 0.9740
# Epoch 46/50
# 1000/1000 [==============================] - 0s 30us/sample - loss: 0.0918 - accuracy: 0.9670
# Epoch 47/50
# 1000/1000 [==============================] - 0s 34us/sample - loss: 0.0819 - accuracy: 0.9770
# Epoch 48/50
# 1000/1000 [==============================] - 0s 35us/sample - loss: 0.0830 - accuracy: 0.9770
# Epoch 49/50
# 1000/1000 [==============================] - 0s 35us/sample - loss: 0.0825 - accuracy: 0.9740
# Epoch 50/50
# 1000/1000 [==============================] - 0s 26us/sample - loss: 0.0823 - accuracy: 0.9770

# %%
plt.plot(history.history['accuracy'])
plt.title('Accuracy')
plt.xlabel('epoch')
plt.legend('accuracy')

# %%
plt.plot(history.history['loss'])
plt.title('Loss')
plt.xlabel('epoch')
plt.legend('Loss')

# %%
def plot_decision_boundary(X, y, model):
    x_span = np.linspace(min(X[:,0]) - 1 , max(X[:,0]) + 1)
    y_span = np.linspace(min(X[:,1]) - 1 , max(X[:,1]) + 1)
    xx , yy = np.meshgrid(x_span , y_span)
    xx_ , yy_ = xx.ravel() , yy.ravel()
    grid = np.c_[xx_,yy_]
    pred_func = model.predict(grid)
    z = pred_func.reshape(xx.shape)
    plt.contourf(xx,yy,z)
    plt.scatter(X[:n_pts, 0], X[:n_pts,  1])
    plt.scatter(X[n_pts:, 0], X[n_pts:,  1])

# %%
plot_decision_boundary(X,y,model)

# %%
plot_decision_boundary(X,y,model)
x = 10.5
y = 7.6
point = np.array([[x,y]])
predection = model.predict(point)
plt.plot([x],[y], marker='o', markersize = 11 , color='red')
print("Predection is: ", predection)
# Out:
# Predection is:  [[0.76169604]]
